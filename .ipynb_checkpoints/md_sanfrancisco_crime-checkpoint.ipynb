# %% [markdown]
# # San Francisco Police Department Crime Rate Reports

# %% [markdown]
# For this project we will be analyzing Sa Francisco Police Department Crime Rate reports from [Kaggle](https://www.kaggle.com/psmavi104/san-francisco-crime-data). The data contains the
#
# * Incident_Datetime
# * Incident_Time
# * Incident_Year
# * Incident_Day_of_Week
# * Report_Datetime
# * Incident_ID
# * Row_ID
# * Incident_Number
# * CAD_Number
# * Report_Type_Code
# * Report_Type_Description
# * Filed_Online
# * Incident_Code
# * Incident_Category
# * Incident_Subcategory
# * Incident_Description
# * Resolution
# * Intersection
# * CNN
# * Police_District
# * Analysis_Neighborhood
# * Supervisor_District
# * Latitude
# * Longitude
# * point
# * SF_Find_Neighborhoods
# * Current_Police_Districts
# * Current_Supervisor_Districts
# * Analysis_Neighborhoods
# * HSOC_Zones_as_of_2018-06-05
# * OWED_Public_Spaces
# * Central_Market/Tenderloin_Boundary_Polygon_-_Updated
# * Parks_Alliance_CPSI_27+TL_sites

# %% [markdown]
# ## Data and Setup

# %% [markdown]
# ** Import some libraries **

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import sklearn.preprocessing
import warnings
from wordcloud import WordCloud

# %matplotlib inline
sns.set_style("darkgrid")
warnings.filterwarnings("ignore")

# %% [markdown]
# ** Read in the csv file as a dataframe called df **

# %%
df  = pd.read_csv('SFCD_2018.csv')

# %% [markdown]
# ## Exploring Data

# %%
df.columns = df.columns.str.strip().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
df.columns
# Out:
# Index(['Incident_Datetime', 'Incident_Date', 'Incident_Time', 'Incident_Year',
#        'Incident_Day_of_Week', 'Report_Datetime', 'Row_ID', 'Incident_ID',
#        'Incident_Number', 'CAD_Number', 'Report_Type_Code',
#        'Report_Type_Description', 'Filed_Online', 'Incident_Code',
#        'Incident_Category', 'Incident_Subcategory', 'Incident_Description',
#        'Resolution', 'Intersection', 'CNN', 'Police_District',
#        'Analysis_Neighborhood', 'Supervisor_District', 'Latitude', 'Longitude',
#        'point', 'SF_Find_Neighborhoods', 'Current_Police_Districts',
#        'Current_Supervisor_Districts', 'Analysis_Neighborhoods',
#        'HSOC_Zones_as_of_2018-06-05', 'OWED_Public_Spaces',
#        'Central_Market/Tenderloin_Boundary_Polygon_-_Updated',
#        'Parks_Alliance_CPSI_27+TL_sites'],
#       dtype='object')

# %%
# plt.rcParams['figure.figsize'] = (10, 8)
# plt.style.use('bmh')
# wc = WordCloud(background_color = 'pink', width = 1500, height = 1500).generate(str(df['Incident_Description']))
# plt.imshow(wc)
# plt.axis('off')
# plt.show()

# %%
df.isnull().sum()
# Out:
# Incident_Datetime                                            0
# Incident_Date                                                0
# Incident_Time                                                0
# Incident_Year                                                0
# Incident_Day_of_Week                                         0
# Report_Datetime                                              0
# Row_ID                                                       0
# Incident_ID                                                  0
# Incident_Number                                              0
# CAD_Number                                               50964
# Report_Type_Code                                             0
# Report_Type_Description                                      0
# Filed_Online                                            176347
# Incident_Code                                                0
# Incident_Category                                           19
# Incident_Subcategory                                        19
# Incident_Description                                         0
# Resolution                                                   0
# Intersection                                             13028
# CNN                                                      13028
# Police_District                                              0
# Analysis_Neighborhood                                    13084
# Supervisor_District                                      13028
# Latitude                                                 13028
# Longitude                                                13028
# point                                                    13028
# SF_Find_Neighborhoods                                    17480
# Current_Police_Districts                                 13371
# Current_Supervisor_Districts                             13062
# Analysis_Neighborhoods                                   13118
# HSOC_Zones_as_of_2018-06-05                             173480
# OWED_Public_Spaces                                      212567
# Central_Market/Tenderloin_Boundary_Polygon_-_Updated    193797
# Parks_Alliance_CPSI_27+TL_sites                         221161
# dtype: int64

# %%
sns.heatmap(df.corr(),center =0)

# %%
df_2 = df.drop(['CAD_Number', 'Report_Type_Code', 'Filed_Online', 'Incident_Code',
       'Incident_Category', 'Incident_Subcategory', 'Intersection', 'CNN', 'Police_District',
       'Analysis_Neighborhood', 'Supervisor_District',
       'point', 'SF_Find_Neighborhoods', 'Current_Police_Districts',
       'Current_Supervisor_Districts', 'Analysis_Neighborhoods',
       'HSOC_Zones_as_of_2018-06-05', 'OWED_Public_Spaces',
       'Central_Market/Tenderloin_Boundary_Polygon_-_Updated'], axis = 1)

# %%
df_2.head()
# Out:
#         Incident_Datetime Incident_Date Incident_Time  Incident_Year  \
# 0  2018/07/18 01:30:00 PM    2018/07/18         13:30           2018
# 1  2019/04/08 05:25:00 AM    2019/04/08         05:25           2019
# 2  2019/06/05 02:00:00 PM    2019/06/05         14:00           2019
# 3  2019/04/16 08:20:00 PM    2019/04/16         20:20           2019
# 4  2019/06/10 11:00:00 AM    2019/06/10         11:00           2019
#
#   Incident_Day_of_Week         Report_Datetime       Row_ID  Incident_ID  \
# 0            Wednesday  2018/07/18 01:31:00 PM  69250964070       692509
# 1               Monday  2019/04/13 01:34:00 PM  79165671000       791656
# 2            Wednesday  2019/06/05 02:30:00 PM  81006072000       810060
# 3              Tuesday  2019/04/17 12:21:00 AM  79171306244       791713
# 4               Monday  2019/06/10 11:00:00 AM  81012372000       810123
#
#    Incident_Number Report_Type_Description               Incident_Description  \
# 0        180536729                 Initial              Suspicious Occurrence
# 1        196076240        Coplogic Initial                      Lost Property
# 2        190416337                 Initial                    Found  Property
# 3        196076024        Coplogic Initial  Theft, From Locked Vehicle, >$950
# 4        190393440      Initial Supplement                    Found  Property
#
#        Resolution   Latitude   Longitude  Parks_Alliance_CPSI_27+TL_sites
# 0       Unfounded        NaN         NaN                              NaN
# 1  Open or Active        NaN         NaN                              NaN
# 2  Open or Active  37.782685 -122.422464                              NaN
# 3  Open or Active        NaN         NaN                              NaN
# 4  Open or Active  37.779091 -122.464145                              NaN

# %%
df_2.dropna(how='all')
# Out:
#              Incident_Datetime Incident_Date Incident_Time  Incident_Year  \
# 0       2018/07/18 01:30:00 PM    2018/07/18         13:30           2018
# 1       2019/04/08 05:25:00 AM    2019/04/08         05:25           2019
# 2       2019/06/05 02:00:00 PM    2019/06/05         14:00           2019
# 3       2019/04/16 08:20:00 PM    2019/04/16         20:20           2019
# 4       2019/06/10 11:00:00 AM    2019/06/10         11:00           2019
# 5       2019/06/10 06:57:00 PM    2019/06/10         18:57           2019
# 6       2019/04/18 01:42:00 PM    2019/04/18         13:42           2019
# 7       2019/06/10 01:30:00 AM    2019/06/10         01:30           2019
# 223937        196022168        Coplogic Initial
# 223938        190131052      Vehicle Supplement
# 223939        180841631      Initial Supplement
# 223940        190183025                 Initial
# 223941        196046776        Coplogic Initial
# 223942        190245318                 Initial
# 223943        190104275                 Initial
# 223944        190057925                 Initial
# 223945        190244934                 Initial
# 223946        196050410        Coplogic Initial
# 223947        190204778                 Initial
# 223948        190243845                 Initial
# 223949        190192327                 Initial
# 223950        190078012      Initial Supplement
# 223951        190163754                 Initial
# 223952        190099159                 Initial
# 223953        190210769                 Initial
# 223954        190069049                 Initial
# 223955        190183116                 Initial
# 223956        190214614                 Initial
# 223957        190090878                 Initial
#
#                                      Incident_Description  \
# 0                                   Suspicious Occurrence
# 1                                           Lost Property
# 2                                         Found  Property
# 3                       Theft, From Locked Vehicle, >$950
# 4                                         Found  Property
# 5                                                 Battery
# 6                               Vehicle, Recovered, Truck
# 7                                                 Battery
# 8               Malicious Mischief, Vandalism to Property
# 9                            Theft, Other Property, >$950
# 10                      Theft, From Locked Vehicle, >$950
# 11                              Vehicle, Recovered, Truck
# 12               Malicious Mischief, Vandalism to Vehicle
# 13                                      Robbery, W/ Force
# 14                                      Robbery, W/ Force
# 15              Malicious Mischief, Vandalism to Property
# 16                                            Trespassing
# 17                                         Heroin Offense
# 18              Malicious Mischief, Vandalism to Property
# 19              Malicious Mischief, Vandalism to Property
# 20      Resisting, Delaying, or Obstructing  Peace Off...
# 21                                Methamphetamine Offense
# 22                               Vehicle, Recovered, Auto
# 23                           Theft, Other Property, >$950
# 24                                Mental Health Detention
# 25                                      Terrorist Threats
# 26                        Burglary, Store, Forcible Entry
# 27                                                Battery
# 28                               Vehicle, Recovered, Auto
# 29                                  Suspicious Occurrence
# ...                                                   ...
# 223928                                       Found Person
# 223929                                            Battery
# 223930                  Theft, From Locked Vehicle, >$950
# 223931                          Theft, Shoplifting, >$950
# 223932                  Theft, From Locked Vehicle, >$950
# 223933                           Cocaine, Base/rock, Sale
# 223934                  Theft, From Locked Vehicle, >$950
# 223935                           Theft, Shoplifting, <$50
# 223936                             Embezzlement (general)
# 223937                  Theft, From Locked Vehicle, >$950
# 223938                           Vehicle, Recovered, Auto
# 223939                   Warrant Arrest, Local SF Warrant
# 223940      Battery, former Spouse or Dating Relationship
# 223941                    Theft, Other Property, $50-$200
# 223942                           Traffic Violation Arrest
# 223943     False Personation to Receive Money or Property
# 223944               Assault, Aggravated, W/ Other Weapon
# 223945                       Theft, Other Property, >$950
# 223946                  Theft, From Locked Vehicle, >$950
# 223947          Burglary, Non-residential, Forcible Entry
# 223948                         Driving, No License Issued
# 223949                   Theft, From Locked Vehicle, <$50
# 223950                             Search Warrant Service
# 223951                     Violation of Restraining Order
# 223952                  Theft, From Locked Vehicle, >$950
# 223953                                         Conspiracy
# 223954                                            Suicide
# 223955          Burglary, Apartment House, Unlawful Entry
# 223956                            Investigative Detention
# 223957                       Theft, Shoplifting, $50-$200
#
#                      Resolution   Latitude   Longitude  \
# 0                     Unfounded        NaN         NaN
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
# 5                                   NaN
# 6                                   NaN
# 7                                   NaN
# 8                                   NaN
# 9                                   NaN
# 10                                  NaN
# 11                                  NaN
# 12                                  NaN
# 13                                  NaN
# 14                                  NaN
# 15                                  NaN
# 16                                  NaN
# 17                                  NaN
# 18                                  NaN
# 19                                  NaN
# 20                                  NaN
# 21                                  NaN
# 22                                  NaN
# 23                                  NaN
# 24                                  NaN
# 25                                  NaN
# 26                                  NaN
# 27                                  NaN
# 28                                  NaN
# 29                                  NaN
# ...                                 ...
# 223928                              NaN
# 223929                              NaN
# 223930                              NaN
# 223931                              NaN
# 223932                              NaN
# 223933                              NaN
# 223934                              NaN
# 223935                              NaN
# 223936                              NaN
# 223937                              NaN
# 223938                              NaN
# 223939                              NaN
# 223940                              NaN
# 223941                              NaN
# 223942                              NaN
# 223943                              NaN
# 223944                              NaN
# 223945                              NaN
# 223946                              NaN
# 223947                              NaN
# 223948                              NaN
# 223949                              NaN
# 223950                              NaN
# 223951                              NaN
# 223952                              NaN
# 223953                              NaN
# 223954                              NaN
# 223955                              NaN
# 223956                              NaN
# 223957                              NaN
#
# [223958 rows x 15 columns]

# %%
df_2.shape
# Out:
# (223958, 15)

# %%
#df.Incident_Description.value_counts().plot.bar()

# %%
# plt.rcParams['figure.figsize'] = (10, 8)
# plt.style.use('bmh')
# wc = WordCloud(background_color = 'white', width = 1800, height = 1700).generate(str(df_2['Incident_Description']))
# plt.imshow(wc)
# plt.axis('off')
# plt.show()

# %%
sns.heatmap(df_2.corr(),center =0)

# %%
df_2['Incident_Datetime'] = pd.to_datetime(df_2['Incident_Datetime'])

# %%
df_2.columns
# Out:
# Index(['Incident_Datetime', 'Incident_Date', 'Incident_Time', 'Incident_Year',
#        'Incident_Day_of_Week', 'Report_Datetime', 'Row_ID', 'Incident_ID',
#        'Incident_Number', 'Report_Type_Description', 'Incident_Description',
#        'Resolution', 'Latitude', 'Longitude',
#        'Parks_Alliance_CPSI_27+TL_sites'],
#       dtype='object')

# %%
df_2['date'] = df_2['Incident_Datetime'].apply(lambda t: t.date())

# %%
df_2['month'] = df_2['Incident_Datetime'].apply(lambda time: time.month)

# %%
df_2['hour'] = df_2['Incident_Datetime'].apply(lambda time: time.hour)

# %%
df_2['day'] = df_2['Incident_Datetime'].apply(lambda time: time.hour)

# %%
df_2.drop(['Incident_Date', 'Incident_Time', 'Incident_Year','Row_ID', 'Incident_ID', 'Report_Type_Description', 'Parks_Alliance_CPSI_27+TL_sites','Incident_Number', 'Report_Datetime','Incident_Datetime'], axis  = 1, inplace=True)

# %%
df_2.dropna(axis=0, inplace=True)

# %%
df_2.head()
# Out:
#   Incident_Day_of_Week                       Incident_Description  \
# 2            Wednesday                            Found  Property
# 4               Monday                            Found  Property
# 5               Monday                                    Battery
# 7               Monday                                    Battery
# 8               Sunday  Malicious Mischief, Vandalism to Property
#
#              Resolution   Latitude   Longitude        date  month  hour  day
# 2        Open or Active  37.782685 -122.422464  2019-06-05      6    14   14
# 4        Open or Active  37.779091 -122.464145  2019-06-10      6    11   11
# 5  Cite or Arrest Adult  37.784449 -122.416072  2019-06-10      6    18   18
# 7        Open or Active  37.723168 -122.442554  2019-06-10      6     1    1
# 8        Open or Active  37.792487 -122.405654  2019-06-09      6    23   23

# %% [markdown]
# ## Basic Questions

# %% [markdown]
# ** What are the top 20 crimes in San Francisco? **

# %%
df_2.Incident_Description.value_counts().head(20).plot(kind='bar')

# %%
from matplotlib.pyplot import figure
figure(num=None, figsize=(20, 6), dpi=80, facecolor='w', edgecolor='k')

# %%
df_2.groupby('Incident_Description')['Longitude'].value_counts().plot()
plt.title('Reasons')
plt.figure(figsize=(20, 6))
#plt.tight_layout()

# %%
#sns.countplot(x='month',data=byMonth,hue='Incident_Description',palette='viridis')

# %%
byMonth = df_2.groupby('Incident_Day_of_Week').count()

# %%
byMonth['Incident_Description'].plot(kind='bar')
